# %%
# -------- NLTK --------
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
text = "I love Natural Language Processing"

print("NLTK Tokenization:", word_tokenize(text))


# -------- TextBlob --------
from textblob import TextBlob

blob = TextBlob(text)
print("TextBlob Sentiment:", blob.sentiment)


# -------- spaCy --------
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

print("spaCy POS Tags:")
for token in doc:
    print(token.text, "->", token.pos_)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# NLTK Tokenization: ['I', 'love', 'Natural', 'Language', 'Processing']
# TextBlob Sentiment: Sentiment(polarity=0.3, subjectivity=0.5)
# spaCy POS Tags:
# I -> PRON
# love -> VERB
# Natural -> PROPN
# Language -> PROPN
# Processing -> NOUN

# %%
import nltk
from nltk.tokenize import word_tokenize
text="the dog is eating food"
tokens=word_tokenize(text)
print(tokens)
# Out:
# ['the', 'dog', 'is', 'eating', 'food']

# %%
from textblob import TextBlob

text="The dog eating food"
blob=TextBlob(text)
print(blob.sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
import spacy
nlp=spacy.load("en_core_web_sm")
text="the dog is eating food"
doc=nlp(text)
for token in doc:
    print(token.text, "->", token.pos_)
# Out:
# the -> DET
# dog -> NOUN
# is -> AUX
# eating -> VERB
# food -> NOUN
